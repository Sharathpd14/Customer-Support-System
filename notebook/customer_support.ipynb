# %%
# testing embed model

from langchain_google_genai import GoogleGenerativeAIEmbeddings

emb = GoogleGenerativeAIEmbeddings(model="gemini-embedding-exp-03-07",output_dimensionality=1536)

len(emb.embed_query("test"))
# Out:
# 1536
